# %% [markdown]
# # Aquí se tratara de seguir el ejemplo avanzado de cobaya.

# %% [markdown]
# Si se desea, se puede seguir el [ejemplo original](https://mybinder.org/v2/gh/CobayaSampler/cobaya/master?filepath=docs%2Fcobaya-example.ipynb).

# %%
# Configuration
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys, platform, os
try:
    from cobaya.run import run
except ImportError:
    sys.path.insert(0,'../../cobaya')
    from cobaya.run import run

# %%
import numpy as np
from scipy import stats

def gauss_ring_logp(x, y):
    return stats.norm.logpdf(np.sqrt(x**2+y**2), loc=1, scale=0.02)

info = {"likelihood": {"ring": gauss_ring_logp}}

# %%
info["params"] = {
    "x": {"prior": {"min": 0, "max": 2}, "ref": 0.5, "proposal": 0.01},
    "y": {"prior": {"min": 0, "max": 2}, "ref": 0.5, "proposal": 0.01}}

# %%
get_r = lambda x,y: np.sqrt(x**2+y**2)
get_theta = lambda x,y: np.arctan(y/x)

info["params"]["r"] = {"derived": get_r}
info["params"]["theta"] = {"derived": get_theta,
                           "latex": r"\theta", "min": 0, "max": np.pi/2}

# N.B.: the options "min" and "max" for theta are not a prior (it is not a sampled parameter!)
# but the ranges used by GetDist to plot and derive marginal distributions for theta.

# %%
# Very non-gaussian shape: increase the default convergence criterion and
# increase limit on tries before chain gets stuck
info["sampler"] = {"mcmc": {"Rminus1_stop": 0.001, "max_tries": 1000}}

from cobaya.run import run
updated_info, sampler = run(info)
# Out:
# [ring] Initialised external likelihood.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (was 2).
# [mcmc] Initial point:
# [mcmc]
#  weight  minuslogpost    x    y         r     theta  minuslogprior  minuslogprior__0        chi2  chi2__ring
#     1.0    105.626257  0.5  0.5  0.707107  0.785398       1.386294          1.386294  208.479925  208.479925
# [mcmc] Sampling! (NB: nothing will be printed until 40 burn-in samples have been obtained)
# [mcmc] Finished burn-in phase: discarded 40 accepted steps.
# [mcmc] Checkpoint: 80 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.618009 after 80 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 160 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 14.781791 after 160 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 240 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 4.361963 after 240 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 320 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 2.018378 after 320 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 400 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.984729 after 400 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 480 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.955052 after 480 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 560 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.293791 after 560 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 640 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.498371 after 640 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 720 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.417307 after 720 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 800 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.381845 after 800 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 880 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.239223 after 880 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 960 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.235300 after 960 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1040 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.187313 after 1040 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1120 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.095321 after 1120 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1200 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.092703 after 1200 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1280 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.112525 after 1280 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1360 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.115911 after 1360 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1440 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.106865 after 1440 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1520 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.117330 after 1520 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1600 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.206552 after 1600 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1680 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.100790 after 1680 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1760 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.086871 after 1760 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1840 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.090894 after 1840 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1920 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.064334 after 1920 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2000 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.052547 after 2000 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2080 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.050204 after 2080 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2160 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.037341 after 2160 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2240 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.048602 after 2240 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2320 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.062421 after 2320 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2400 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.089369 after 2400 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2480 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.078930 after 2480 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2560 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.085520 after 2560 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2640 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.077475 after 2640 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2720 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.089261 after 2720 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2800 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.097261 after 2800 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2880 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.084161 after 2880 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2960 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.075463 after 2960 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3040 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.068289 after 3040 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3120 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.063382 after 3120 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3200 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.051014 after 3200 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3280 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.039874 after 3280 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3360 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.022384 after 3360 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3440 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.022998 after 3440 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3520 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.022861 after 3520 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3600 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.020454 after 3600 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3680 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.020529 after 3680 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3760 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.013896 after 3760 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3840 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.011224 after 3840 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3920 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.010067 after 3920 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4000 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.012139 after 4000 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4080 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.011591 after 4080 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4160 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.004142 after 4160 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4240 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.006554 after 4240 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4320 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.004403 after 4320 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4400 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.
 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.000809 after 18240 accepted steps
# [mcmc] Convergence of bounds: R-1 = 0.030308 after 18240 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 18240 accepted steps.

# %%
from getdist.mcsamples import MCSamplesFromCobaya
import getdist.plots as gdplt

products = sampler#.products()
gdsamples = MCSamplesFromCobaya(updated_info, products["sample"])
gdplot = gdplt.get_subplot_plotter(width_inch=5)
gdplot.triangle_plot(gdsamples, ["x", "y"], filled=True)
gdplot.export("example_adv_ring.png")
gdplot = gdplt.get_subplot_plotter(width_inch=5)
gdplot.plots_1d(gdsamples, ["r", "theta"], nx=2)
gdplot.export("example_adv_r_theta.png")

# %% [markdown]
# # Imposing a Gaussian band along $x=y$

# %%
info["prior"] = {"x_eq_y_band": lambda x, y: stats.norm.logpdf(x - y, loc=0, scale=0.3)}

from cobaya.run import run
updated_info_x_eq_y, sampler_x_eq_y = run(info)
# Out:
# [prior] *WARNING* External prior 'x_eq_y_band' loaded. Mind that it might not be normalized!
# [ring] Initialised external likelihood.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (was 2).
# [mcmc] Initial point:
# [mcmc]
#  weight  minuslogpost    x    y         r     theta  minuslogprior  minuslogprior__0  minuslogprior__x_eq_y_band  \
#     1.0    105.341223  0.5  0.5  0.707107  0.785398        1.10126          1.386294                   -0.285034
#
#        chi2  chi2__ring
#  208.479925  208.479925
# [mcmc] Sampling! (NB: nothing will be printed until 40 burn-in samples have been obtained)
# [mcmc] Finished burn-in phase: discarded 40 accepted steps.
# [mcmc] Checkpoint: 80 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 2.534591 after 80 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 160 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 1.278974 after 160 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 240 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.569550 after 240 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 320 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.323340 after 320 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 400 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.156178 after 400 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 480 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.297738 after 480 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 560 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.170195 after 560 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 640 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.119449 after 640 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 720 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.125554 after 720 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 800 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.080582 after 800 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 880 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.070270 after 880 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 960 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.092525 after 960 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1040 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.066959 after 1040 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1120 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.055377 after 1120 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1200 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.056041 after 1200 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1280 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.022140 after 1280 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1360 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.030913 after 1360 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1440 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.036474 after 1440 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1520 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.039978 after 1520 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1600 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.043514 after 1600 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1680 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.018991 after 1680 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1760 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.019071 after 1760 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1840 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.013032 after 1840 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 1920 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.011170 after 1920 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2000 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.009323 after 2000 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2080 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.008466 after 2080 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2160 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.028443 after 2160 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2240 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.023423 after 2240 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2320 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.008636 after 2320 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2400 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.012316 after 2400 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2480 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.011322 after 2480 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2560 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.012430 after 2560 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2640 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.026413 after 2640 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2720 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.026219 after 2720 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2800 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.020401 after 2800 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2880 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.019974 after 2880 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 2960 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.014718 after 2960 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3040 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.010478 after 3040 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3120 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.010824 after 3120 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3200 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.012431 after 3200 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3280 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.027053 after 3280 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3360 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.019752 after 3360 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3440 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.013812 after 3440 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3520 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.013062 after 3520 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3600 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.015577 after 3600 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3680 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.013656 after 3680 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3760 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.013870 after 3760 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3840 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.013705 after 3840 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 3920 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.006545 after 3920 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4000 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.005746 after 4000 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4080 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.003764 after 4080 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4160 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.003225 after 4160 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4240 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.002149 after 4240 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4320 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.001252 after 4320 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4400 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.011266 after 4400 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4480 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.010019 after 4480 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4560 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.011185 after 4560 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4640 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.011172 after 4640 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4720 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.014849 after 4720 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4800 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.016259 after 4800 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4880 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.011610 after 4880 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 4960 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.015345 after 4960 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 5040 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.014075 after 5040 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 5120 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.006933 after 5120 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 5200 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.006282 after 5200 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 5280 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.008779 after 5280 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 5360 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.011327 after 5360 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 5440 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.009779 after 5440 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 5520 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.011170 after 5520 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 5600 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.011043 after 5600 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 5680 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.005211 after 5680 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 5760 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.003893 after 5760 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 5840 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.004381 after 5840 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 5920 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.004633 after 5920 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 6000 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.007593 after 6000 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 6080 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.010121 after 6080 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 6160 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.010130 after 6160 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 6240 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.010643 after 6240 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 6320 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.014794 after 6320 accepted steps
# [mcmc] Updated covariance matrix of proposal pdf.
# [mcmc] Checkpoint: 6400 samples accepted.
# [mcmc] Ready to check convergence and learn a new proposal covmat
# [mcmc] Convergence of means: R-1 = 0.
# List available derived parameters in the 'output_params' option of the likelihood.
# To make room for that, you need assign the function to the option 'external'.
# Return both the log-likelihood and a dictionary of derived parameters.
def gauss_ring_logp_with_derived(x, y):
    r = np.sqrt(x**2+y**2)
    derived = {"r": r, "theta": np.arctan(y/x)}
    return stats.norm.logpdf(r, loc=1, scale=0.02), derived

info_alt = {"likelihood": {"ring":{
    "external": gauss_ring_logp_with_derived, 
    "output_params": ["r", "theta"] } }
           }

# Now we don't need to *define* (but do need to *mention*) r or theta
# if we want their values included in the chain
info_alt["params"] = {
    "x": {"prior": {"min": 0, "max": 2}, "ref": 0.5, "proposal": 0.01},
    "y": {"prior": {"min": 0, "max": 2}, "ref": 0.5, "proposal": 0.01},
    "r": None,
    "theta": {"latex": r"\theta", "min": 0, "max": np.pi/2}}
# Copy the prior and sampler info from the old one
info_alt["prior"] = info["prior"]
info_alt["sampler"] = info["sampler"]

# And run
updated_info_alt, sampler_alt = run(info_alt)
# Out:
# [prior] *WARNING* External prior 'x_eq_y_band' loaded. Mind that it might not be normalized!
# [ring] Initialised external likelihood.
# [likelihood] *ERROR* Could not find whom to assign output parameters ['r', 'theta'].
# ---------------------------------------------------------------------------
# LoggedError                               Traceback (most recent call last)
# <ipython-input-20-712d90744d5a> in <module>()
#      24
#      25 # And run
# ---> 26 updated_info_alt, sampler_alt = run(info_alt)
#
# ~/miniconda3/lib/python3.6/site-packages/cobaya/run.py in run(info)
#      77     with Model(updated_info[_params], updated_info[_likelihood], updated_info.get(_prior),
#      78                updated_info.get(_theory), modules=info.get(_path_install),
# ---> 79                timing=updated_info.get(_timing), allow_renames=False) as model:
#      80         # Update the updated info with the parameter routes
#      81         keys = ([_likelihood, _theory] if _theory in updated_info else [_likelihood])
#
# ~/miniconda3/lib/python3.6/site-packages/cobaya/model.py in __init__(self, info_params, info_likelihood, info_prior, info_theory, modules, timing, allow_renames)
#      90         self.likelihood = Likelihood(
#      91             self._updated_info[_likelihood], self.parameterization,
# ---> 92             self._updated_info.get(_theory), modules=modules, timing=timing)
#      93
#      94     def info(self):
#
# ~/miniconda3/lib/python3.6/site-packages/cobaya/likelihood.py in __init__(self, info_likelihood, parameterization, info_theory, modules, timing)
#     300                 self._likelihoods[name] = like_class(info, modules=modules, timing=timing)
#     301         # Assign input/output parameters
# --> 302         self._assign_params(parameterization, info_likelihood, info_theory)
#     303         # Do the user-defined post-initialisation, and assign the theory code
#     304         if self.theory:
#
# ~/miniconda3/lib/python3.6/site-packages/cobaya/likelihood.py in _assign_params(self, parameterization, info_likelihood, info_theory)
#     486             raise LoggedError(
#     487                 self.log, "Could not find whom to assign output parameters %r.",
# --> 488                 unassigned_output)
#     489         if multiassigned_output:
#     490             raise LoggedError(
#
# LoggedError: Could not find whom to assign output parameters ['r', 'theta'].
